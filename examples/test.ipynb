# %%
import numpy as np
s1_lon = np.random.normal(0,1,45)
s1_lat = np.random.normal(0,1,45)
s2_lon = np.random.normal(0,1,45)
s2_lat = np.random.normal(0,1,45)

position = np.array([s1_lon, s1_lat, s2_lon, s2_lat]).transpose()

print(range(position.shape[0]))
# Out:
# range(0, 45)

# %%
test = np.repeat((np.nan), (2,))
print(test[0])
# Out:
# nan

# %%
import numpy as np

test = np.arange(100)
test2 = np.arange(0, 100,5)

list(set(test).intersection(test2))
# Out:
# [np.int64(0),
#  np.int64(5),
#  np.int64(10),
#  np.int64(15),
#  np.int64(20),
#  np.int64(25),
#  np.int64(30),
#  np.int64(35),
#  np.int64(40),
#  np.int64(45),
#  np.int64(50),
#  np.int64(55),
#  np.int64(60),
#  np.int64(65),
#  np.int64(70),
#  np.int64(75),
#  np.int64(80),
#  np.int64(85),
#  np.int64(90),
#  np.int64(95)]
